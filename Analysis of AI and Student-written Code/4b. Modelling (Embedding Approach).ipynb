# %%
import pandas as pd
import numpy as np
import scipy as sp
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, precision_recall_curve

# %% [markdown]
# # Modelling with embedding approach

# %%
embed_data = pd.read_csv("ss21_processed_solutions/m0_embedding_data.csv")
embed_data["binary_source"] = embed_data["source"].apply(lambda row: row if row=="student" else "ai")

embed_features = list(embed_data.columns[6:-1])

# %%
X_train_embed, X_test_embed, y_train_embed, y_test_embed = train_test_split(embed_data[embed_features].values, embed_data["binary_source"], test_size=0.3, random_state=0)

# %%
embed_model = GridSearchCV(RandomForestClassifier(random_state=0), param_grid={"n_estimators":np.arange(100,200,10),
                                                                             "max_depth":[10, 20, 30, None], 
                                                                             "max_features":[1, 0.9, 0.8, "sqrt", "log2"]}) 
embed_model.fit(X_train_embed, y_train_embed)
embed_model_results = pd.DataFrame(embed_model.cv_results_)
embed_model_results[embed_model_results["rank_test_score"]==1].head()
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 17       2.619382      0.038713         0.014213    4.006626e-04
# 18       2.795943      0.034647         0.015214    4.002095e-04
# 19       2.981312      0.069427         0.016015    2.336015e-07
# 67       2.592957      0.021904         0.014213    4.009972e-04
# 68       2.753094      0.042828         0.015216    3.995321e-04
#
#    param_max_depth param_max_features param_n_estimators  \
# 17              10                0.9                170
# 18              10                0.9                180
# 19              10                0.9                190
# 67              20                0.9                170
# 68              20                0.9                180
#
#                                                params  split0_test_score  \
# 17  {'max_depth': 10, 'max_features': 0.9, 'n_esti...           0.857143
# 18  {'max_depth': 10, 'max_features': 0.9, 'n_esti...           0.857143
# 19  {'max_depth': 10, 'max_features': 0.9, 'n_esti...           0.857143
# 67  {'max_depth': 20, 'max_features': 0.9, 'n_esti...           0.857143
# 68  {'max_depth': 20, 'max_features': 0.9, 'n_esti...           0.857143
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 17           0.964286           0.928571                1.0
# 18           0.964286           0.928571                1.0
# 19           0.964286           0.928571                1.0
# 67           0.964286           0.928571                1.0
# 68           0.964286           0.928571                1.0
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 17           0.925926         0.935185        0.047472                1
# 18           0.925926         0.935185        0.047472                1
# 19           0.925926         0.935185        0.047472                1
# 67           0.925926         0.935185        0.047472                1
# 68           0.925926         0.935185        0.047472                1

# %%
embed_model = RandomForestClassifier(random_state=0, max_depth=10, max_features=0.9, n_estimators=190)
embed_model.fit(X_train_embed, y_train_embed)
print("Accuracy on test set:", np.round(accuracy_score(y_test_embed, embed_model.predict(X_test_embed)), 3)*100, "%")
# Out:
# Accuracy on test set: 96.7 %

# %%
misclassified = y_test_embed != embed_model.predict(X_test_embed)
(embed_data.loc[misclassified.index[misclassified]]["source"].value_counts() / embed_data.loc[y_test_embed.index]["source"].value_counts()).dropna() * 100
# Out:
# student    6.451613
# Name: source, dtype: float64

# %% [markdown]
# ## Classifying each source of data

# %%
for source in embed_data["source"].unique()[:-1]:
    embed_model = RandomForestClassifier(random_state=0, max_depth=10, max_features=0.9, n_estimators=190)
    embed_model.fit(embed_data[embed_data["source"] != source][embed_features], embed_data[embed_data["source"] != source]["binary_source"])
    print(f"Accuracy on classifying {source}:", np.round(accuracy_score(embed_data[embed_data["source"] == source]["binary_source"], 
                                                            embed_model.predict(embed_data[embed_data["source"] == source][embed_features])), 3)*100, "%")
# Out:
# Accuracy on classifying gpt3.5: 0.0 %
# Accuracy on classifying bing: 46.400000000000006 %
# Accuracy on classifying bard: 0.0 %
# Accuracy on classifying gpt4: 51.6 %

# %% [markdown]
# ## Testing the optimised embedded solutions on the model

# %%
optimised_data = pd.read_csv("ss21_processed_solutions/optimised_embedding_data.csv")
optimised_data["binary_source"] = optimised_data["source"].apply(lambda row: row if row=="student" else "ai")

# %%
full_model = RandomForestClassifier(random_state=0, max_depth=10, max_features=0.9, n_estimators=190)
full_model.fit(embed_data[embed_features].values, embed_data["binary_source"])
# Out:
# RandomForestClassifier(max_depth=10, max_features=0.9, n_estimators=190,
#                        random_state=0)

# %%
predictions = pd.concat([pd.DataFrame(full_model.predict_proba(optimised_data[embed_features].values), columns=["Probability AI", "Probability Human"]),
                        optimised_data.reset_index(drop=True)], axis=1)
predictions.iloc[:,:8].sort_values("Probability Human")
# Out:
#     Probability AI  Probability Human     source milestone      name  style  \
# 9         0.947368           0.052632  optimised        m0        13    NaN
# 17        0.900000           0.100000  optimised        m0        20    NaN
# 14        0.884211           0.115789  optimised        m0        18    NaN
# 2         0.863158           0.136842  intervene        m0  natasha2    NaN
# 19        0.821053           0.178947  optimised        m0         4    NaN
# 6         0.773684           0.226316  optimised        m0        10    NaN
# 8         0.768421           0.231579  optimised        m0        12    NaN
# 16        0.757895           0.242105  optimised        m0         2    NaN
# 10        0.721053           0.278947  optimised        m0        14    NaN
# 21        0.700000           0.300000  optimised        m0         6    NaN
# 13        0.678947           0.321053  optimised        m0        17    NaN
# 5         0.652632           0.347368  optimised        m0         1    NaN
# 11        0.652632           0.347368  optimised        m0        15    NaN
# 18        0.652632           0.347368  optimised        m0         3    NaN
# 15        0.605263           0.394737  optimised        m0        19    NaN
# 7         0.600000           0.400000  optimised        m0        11    NaN
# 1         0.552632           0.447368  intervene        m0  natasha1    NaN
# 24        0.531579           0.468421  optimised        m0         9    NaN
# 20        0.531579           0.468421  optimised        m0         5    NaN
# 23        0.505263           0.494737  optimised        m0         8    NaN
# 22        0.389474           0.610526  optimised        m0         7    NaN
# 12        0.352632           0.647368  optimised        m0        16    NaN
# 4         0.205263           0.794737  intervene        m0  natasha4    NaN
# 3         0.157895           0.842105  intervene        m0  natasha3    NaN
# 0         0.157895           0.842105  intervene        m0    dennis    NaN
#
#     version                                               code
# 9       NaN  package thkoeln.st.st2praktikum.exercise;\n\ni...
# 17      NaN  package thkoeln.st.st2praktikum.exercise;\n\ni...
# 14      NaN  package thkoeln.st.st2praktikum.exercise;\n\ni...
# 2       NaN  package thkoeln.st.st2praktikum.exercise;\n\ni...
# 19      NaN  package thkoeln.st.st2praktikum.exercise;\n\ni...
# 6       NaN  package thkoeln.st.st2praktikum.exercise;\n\ni...
# 8       NaN  package thkoeln.st.st2praktikum.exercise;\n\ni...
# 16      NaN  package thkoeln.st.st2praktikum.exercise;\n\ni...
# 10      NaN  package thkoeln.st.st2praktikum.exercise;\n\ni...
# 21      NaN  package thkoeln.st.st2praktikum.exercise;\n\ni...
# 13      NaN  package thkoeln.st.st2praktikum.exercise;\n\ni...
# 5       NaN  package thkoeln.st.st2praktikum.exercise;\n\ni...
# 11      NaN  package thkoeln.st.st2praktikum.exercise;\n\nc...
# 18      NaN  package thkoeln.st.st2praktikum.exercise;\n\ni...
# 15      NaN  package thkoeln.st.st2praktikum.exercise;\n\ni...
# 7       NaN  package thkoeln.st.st2praktikum.exercise;\n\ni...
# 1       NaN  package thkoeln.st.st2praktikum.exercise;\n\ni...
# 24      NaN  package thkoeln.st.st2praktikum.exercise;\n\ni...
# 20      NaN  // Package for the class\npackage thkoeln.st.s...
# 23      NaN  package thkoeln.st.st2praktikum.exercise;\n\ni...
# 22      NaN  package thkoeln.st.st2praktikum.exercise;\n\np...
# 12      NaN  package thkoeln.st.st2praktikum.exercise;\n\nc...
# 4       NaN  package thkoeln.st.st2praktikum.exercise;\n\np...
# 3       NaN  package thkoeln.st.st2praktikum.exercise;\n\nc...
# 0       NaN  package thkoeln.st.st2praktikum.exercise;\n\np...
